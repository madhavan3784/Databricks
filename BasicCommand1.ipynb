# %%
print ("hello world")

# %%
# %sql
select 'hello world'

# %% [markdown]
# Title 1
# Subtitle 1
# Section A

# %%
# %fs ls '/databricks-datasets/'

# %%
# %run ./Demo/setup

# %%
print(Full_name)

# %%
dbutils.fs.help()

# %%
files=dbutils.fs.ls("dbfs:/")
display(files)

# %%
WS=dbutils.fs.ls('dbfs:/Workspace/')
display (WS)
DS=dbutils.fs.ls('dbfs:/databricks-datasets/')
display (DS)
